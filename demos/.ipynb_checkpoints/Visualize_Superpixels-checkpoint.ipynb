# %% [markdown]
# # Demo 2: Visualizing Superpixels

# %% [markdown]
# The superpixels shown here are computed on the fly and found using skimage's implementation of SLIC superpixels.

# %%
import numpy as np
import scipy as sp
# %pylab inline

from RecipeWatchRelated import *
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
sd = StorageDelegate()
video = sd.get_random_video()
frame = video.get_random_frame()

# %%
plt.imshow(frame.visualize_raw())

# %%
plt.imshow(frame.visualize_superpixels())
