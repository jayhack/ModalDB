# %% [markdown]
# # Demo 1: Visualizing Images

# %% [markdown]
# This demo will walk you through how to load in relevant data and how to visualize masks on images.

# %%
from pprint import pprint
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
# %pylab inline

from RecipeWatchRelated import *
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Loading Data:
# -------------
# You can gain access to the data in its current storage format through the *StorageDelegate* class. It takes a single, optional argument, *data_dir*, that specifies the location of the directory containing all the data. (This is, by default, PROJECT_DIR/data/cpmc/CPMC, where PROJECT_DIR is set in configure.sh)

# %%
sd = StorageDelegate()
video = sd.get_random_video()
print video
frame = video.get_random_frame()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-2-1354716a7781> in <module>()
# ----> 1 sd = StorageDelegate()
#       2 videos = sd.videos
#       3 print '===[ Indexed Videos: ]==='
#       4 pprint(videos.keys())
#
# /Users/jayhack/Academics/CS/Robobrain/Code/RecipeWatchRelated/src/RecipeWatchRelated/StorageDelegate.py in __init__(self, data_dir)
#      26                 self.data_dir = data_dir
#      27                 self.video_dirs = self.get_video_dirs(self.data_dir)
# ---> 28                 self.videos = self.get_videos(self.video_dirs)
#      29
#      30
#
# /Users/jayhack/Academics/CS/Robobrain/Code/RecipeWatchRelated/src/RecipeWatchRelated/StorageDelegate.py in get_videos(self, video_dirs)
#      40                         returns dict: VideoName -> Video
#      41 		"""
# ---> 42                 return {name:Video(name, video_dir) for name, video_dir in video_dirs.items()}
#      43
#      44
#
# /Users/jayhack/Academics/CS/Robobrain/Code/RecipeWatchRelated/src/RecipeWatchRelated/StorageDelegate.py in <dictcomp>((name, video_dir))
#      40                         returns dict: VideoName -> Video
#      41 		"""
# ---> 42                 return {name:Video(name, video_dir) for name, video_dir in video_dirs.items()}
#      43
#      44
#
# /Users/jayhack/Academics/CS/Robobrain/Code/RecipeWatchRelated/src/RecipeWatchRelated/Video.py in __init__(self, name, video_dir)
#      44                 #=====[ Get names/paths ]=====
#      45                 self.frame_names = self.get_frame_names()
# ---> 46                 self.data_paths = self.get_data_paths()
#      47
#      48                 #=====[ Get frames      ]=====
#
# /Users/jayhack/Academics/CS/Robobrain/Code/RecipeWatchRelated/src/RecipeWatchRelated/Video.py in get_data_paths(self)
#      83                         path_list.append(paths)
#      84                 self.frame_datapaths = pd.DataFrame(path_list)
# ---> 85                 self.frame_datapaths['clusters_exist'] = self.frame_datapaths['masks'].apply(os.path.exists)
#      86                 self.frame_datapaths['decoupled'] = self.frame_datapaths['cscores'].apply(os.path.exists)
#      87
#
# /Users/jayhack/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1682             return self._getitem_multilevel(key)
#    1683         else:
# -> 1684             return self._getitem_column(key)
#    1685
#    1686     def _getitem_column(self, key):
#
# /Users/jayhack/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1689         # get column
#    1690         if self.columns.is_unique:
# -> 1691             return self._get_item_cache(key)
#    1692
#    1693         # duplicate columns & possible reduce dimensionaility
#
# /Users/jayhack/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1050         res = cache.get(item)
#    1051         if res is None:
# -> 1052             values = self._data.get(item)
#    1053             res = self._box_item_values(item, values)
#    1054             cache[item] = res
#
# /Users/jayhack/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in get(self, item)
#    2535
#    2536             if not isnull(item):
# -> 2537                 loc = self.items.get_loc(item)
#    2538             else:
#    2539                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /Users/jayhack/anaconda/lib/python2.7/site-packages/pandas/core/index.pyc in get_loc(self, key)
#    1154         loc : int if unique index, possibly slice or mask if not
#    1155         """
# -> 1156         return self._engine.get_loc(_values_from_object(key))
#    1157
#    1158     def get_value(self, series, key):
#
# /Users/jayhack/anaconda/lib/python2.7/site-packages/pandas/index.so in pandas.index.IndexEngine.get_loc (pandas/index.c:3650)()
#
# /Users/jayhack/anaconda/lib/python2.7/site-packages/pandas/index.so in pandas.index.IndexEngine.get_loc (pandas/index.c:3577)()
#
# KeyError: 'masks'

# %% [markdown]
# Viewing/Visualizing Frames
# --------------------------
# you can access a given video using *sd.get_video(video_name)* or *sd.get_random_video()*; likewise, you can access frames from videos using *video.get_frame(timestep)* or *video.get_random_frame()*. Printing a video to stdout will provide some baseline statistics on it

# %%
video = sd.get_video('cpmc_UMiCy8EH1go')
frame = video.get_random_frame()
print video
# Out:
# =====[ Video: cpmc_UMiCy8EH1go ]=====
# # Frames: 719
# # Frames with Clusters Marked: 269

# %%
# Visualize the raw frame:
plt.imshow(frame.visualize_raw())

# %%
# Visualize the frame with the 0th mask applied
plt.imshow(frame.visualize_mask(0))
