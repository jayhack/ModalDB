# %% [markdown]
# # Vizualizing Object Proposal Clusters

# %% [raw]
# • Object proposals generated by CPMC
# • Featurized by a Caffe CNN, then normalized with L2 norm
# • Clustered by KMeans, with k=25

# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
from RecipeWatchRelated import *
from RecipeWatchRelated.visualization_utils import load_cluster_data, visualize_cluster_sample
# %pylab inline

sd = StorageDelegate() 
df = load_cluster_data('../data')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## CLUSTER 1

# %%
visualize_cluster_sample(sd, df, 1)

# %% [markdown]
# ## CLUSTER 2

# %%
visualize_cluster_sample(sd, df, 2)

# %% [markdown]
# ## CLUSTER 3

# %%
visualize_cluster_sample(sd, df, 3)

# %% [markdown]
# ## CLUSTER 4

# %%
visualize_cluster_sample(sd, df, 4)

# %% [markdown]
# ## CLUSTER 5

# %%
visualize_cluster_sample(sd, df, 5)

# %% [markdown]
# ## CLUSTER 6

# %%
visualize_cluster_sample(sd, df, 6)
